# %% [markdown]
# # Counting Point Mutations
# <https://rosalind.info/problems/hamm/>

# %%
DNA_1 = '...'
DNA_2 = '...'


tmpList = []
for nuc, n in zip(DNA_1, DNA_2):
    if nuc != n:
        tmpList.append(1)

print(sum(tmpList))
# Out:
# 512
